# %% [markdown]
# # Exploratory Analysis
#
# Run `python experiments/run_simulation.py` before using this notebook.

# %%
import pandas as pd

logs = pd.read_csv('../data/synthetic/production_logs.csv')
logs.head()
