# %% [markdown]
# # Generate Paper Figures
#
# Run `python experiments/run_fairness_drift_experiment.py` to regenerate all CSV and PNG outputs.

# %%
import pandas as pd

fairness = pd.read_csv('../results/tables/fairness_metrics.csv')
fairness.head()
